# %%
# %env DINO_URL=https://chromedino.com/
# Out:
# env: DINO_URL=https://chromedino.com/

# %%
import gym
import gym_chrome_dino

env = gym.make('ChromeDino-v0')

# %%
game = env.unwrapped.game

while True:
    game.press_up()
    print("Obstacle H Distance " + str(game.get_nearest_obstacle_horizontal_distance()))
    print("Obstacle V Distance " + str(game.get_nearest_obstacle_vertical_distance()))
    print("Dino position X " + str(game.get_dino_x_position()))
    print("Dino position Y " + str(game.get_dino_y_position()))
    print("Width next obstacle " + str(game.get_nearest_obstacle_width()))
    print("Height next obstacle " + str(game.get_nearest_obstacle_height()))
# Out:
# 0
# Obstacle H Distance 0
# Obstacle V Distance -5
# 0
# Dino position X 0
# Dino position Y 6
# Width next obstacle 0
# Height next obstacle 0
# 0
# Obstacle H Distance 0
# Obstacle V Distance -26
# 0
# Dino position X 0
# Dino position Y 31
# Width next obstacle 0
# Height next obstacle 0
# 0
# Obstacle H Distance 0
# Obstacle V Distance -75
# 0
# Dino position X 0
# Dino position Y 84
# Width next obstacle 0
# Height next obstacle 0
# 7
# Obstacle H Distance -7
# Obstacle V Distance -72
# 9
# Dino position X 11
# Dino position Y 54
# Width next obstacle 0
# Height next obstacle 0
# 27
# Obstacle H Distance -27
# Obstacle V Distance -7
# 31
# Dino position X 33
# Dino position Y 5
# Width next obstacle 0
# Height next obstacle 0
# 43
# Obstacle H Distance -43
# Obstacle V Distance -6
# 45
# Dino position X 45
# Dino position Y 8
# Width next obstacle 0
# Height next obstacle 0
# 45
# Obstacle H Distance -45
# Obstacle V Distance -23
# 45
# Dino position X 45
# Dino position Y 23
# ...
