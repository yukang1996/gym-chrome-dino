# %%
# %env DINO_URL=https://chromedino.com/

# %%
import gym
from selenium.common.exceptions import WebDriverException, NoSuchWindowException
import random
import gym_chrome_dino

env = gym.make('ChromeDinoGA-v0')

game = env.unwrapped.game

while True:

    try:
        if random.uniform(0.0,1.0) >= 0.5:
            print(env.step(1))
            print(game.get_score())
        else :
            print(env.step(0))
    except (NoSuchWindowException, WebDriverException):
        print('User closed the window')
        pass
# Out:
# /home/madog/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# (array([  0.,  79., 600.,  82.,   0.,   0., 600.,  98.,   0.,   0.,   6.]), 0.1, False, {})
# (array([  0.,  37., 600., 119.,   0.,   0., 600., 130.,   0.,   0.,   6.]), 0.1, False, {})
# (array([  0.,  12., 600., 144.,   0.,   0., 600., 148.,   0.,   0.,   6.]), 0.1, False, {})
# (array([  0.,   2., 600., 147.,   0.,   0., 600., 143.,   0.,   0.,   6.]), 0.1, False, {})
# (array([  0.,  13., 600., 133.,   0.,   0., 600., 124.,   0.,   0.,   6.]), 0.1, False, {})
# (array([  0.,  32., 600., 112.,   0.,   0., 600.,  98.,   0.,   0.,   6.]), 0.1, False, {})
# (array([  1.,  82., 598.,  77.,   0.,   0., 597.,  95.,   0.,   0.,   6.]), 0.1, False, {})
# 1
# (array([  8.,  22., 592., 132.,   0.,   0., 590., 139.,   0.,   0.,   6.]), 0.1, False, {})
# 2
# (array([ 12.,   7., 586., 144.,   0.,   0., 586., 145.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 19.,  13., 580., 130.,   0.,   0., 579., 120.,   0.,   0.,   6.]), 0.1, False, {})
# 4
# (array([ 21.,  42., 579., 101.,   0.,   0., 579.,  86.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  87., 579.,  73.,   0.,   0., 579.,  91.,   0.,   0.,   6.]), 0.1, False, {})
# 6
# (array([ 21.,  42., 579., 115.,   0.,   0., 579., 127.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  14., 579., 139.,   0.,   0., 579., 144.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,   4., 579., 146.,   0.,   0., 579., 143.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  25., 579., 120.,   0.,   0., 579., 108.,   0.,   0.,   6.]), 0.1, False, {})
# 10
# (array([ 21.,  56., 579.,  76.,   0.,   0., 579.,  59.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  82., 579.,  77.,   0.,   0., 579., 104.,   0.,   0.,   6.]), 0.1, False, {})
# 13
# (array([ 21.,   7., 579., 146.,   0.,   0., 579., 151.,   0.,   0.,   6.]), 0.1, False, {})
# 15
# (array([ 21.,   0., 579., 149.,   0.,   0., 579., 144.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  13., 579., 132.,   0.,   0., 579., 122.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  35., 579., 101.,   0.,   0., 579.,  85.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  85., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  82., 579.,  78.,   0.,   0., 579., 104.,   0.,   0.,   6.]), 0.1, False, {})
# 24
# (array([ 21.,  25., 579., 134.,   0.,   0., 579., 146.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,   2., 579., 147.,   0.,   0., 579., 143.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  27., 579., 117.,   0.,   0., 579., 104.,   0.,   0.,   6.]), 0.1, False, {})
# 28
# (array([ 21.,  61., 579.,  80.,   0.,   0., 579.,  60.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  80., 579.,  89.,   0.,   0., 579., 112.,  17.,  35.,   6.]), 0.1, False, {})
# 31
# (array([ 21.,  11., 515., 100.,  17.,  35., 503., 104.,  17.,  35.,   6.]), 0.1, False, {})
# 33
# (array([ 21.,   8., 461.,  93.,  17.,  35., 449.,  85.,  17.,  35.,   6.]), 0.1, False, {})
# 34
# (array([ 21.,  51., 411.,  36.,  17.,  35., 400.,  16.,  17.,  35.,   6.]), 0.1, False, {})
# 35
# (array([ 21.,  82., 366.,  32.,  17.,  35., 355.,  51.,  17.,  35.,   6.]), 0.1, False, {})
# 36
# (array([ 21.,  25., 321.,  89.,  17.,  35., 310.,  96.,  17.,  35.,   6.]), 0.1, False, {})
# 38
# (array([ 21.,   4., 293., 102.,  17.,  35., 283., 103.,  17.,  35.,   6.]), 0.1, False, {})
# (array([ 21.,   3., 267., 100.,  17.,  35., 262.,  98.,  17.,  35.,   6.]), 0.1, False, {})
# (array([ 21.,  33., 223.,  66.,  17.,  35., 212.,  52.,  17.,  35.,   6.]), 0.1, False, {})
# 40
# (array([ 21.,  70., 196.,  26.,  17.,  35., 184.,  12.,  17.,  35.,   6.]), 0.1, False, {})
# (array([ 21.,  83., 156.,  32.,  17.,  35., 145.,  51.,  17.,  35.,   6.]), 0.1, False, {})
# 42
# (array([ 21.,  33., 123.,  79.,  17.,  35., 106.,  93.,  17.,  35.,   6.]), 0.1, False, {})
# (array([21.,  6., 52., 94., 17., 35., 36., 87., 17., 35.,  6.]), 0.1, False, {})
# 45
# (array([21., 34., 14., 58., 17., 35., -3., 27., 17., 35.,  6.]), 0.1, False, {})
# (array([ 21.,  82., 216.,  17.,  25.,  50., 205.,  36.,  25.,  50.,   6.]), 0.1, False, {})
# 48
# (array([ 21.,  24., 178.,  76.,  25.,  50., 150.,  87.,  25.,  50.,   6.]), 0.1, False, {})
# (array([21., 17., 86., 65., 25., 50., 55., 22., 25., 50.,  6.]), -1, True, {})
# 52
# (array([21., 87., 34.,  3., 25., 50., 34.,  3., 25., 50.,  6.]), -1, True, {})
# (array([21., 87., 34.,  3., 25., 50., 34.,  3., 25., 50.,  6.]), -1, True, {})
# 52
# (array([21., 87., 34.,  3., 25., 50., 34.,  3., 25., 50.,  6.]), -1, True, {})
# (array([21., 87., 34.,  3., 25., 50., 34.,  3., 25., 50.,  6.]), -1, True, {})
# 52
# (array([21., 87., 34.,  3., 25., 50., 34.,  3., 25., 50.,  6.]), -1, True, {})
# 52
# (array([21., 87., 34.,  3., 25., 50., 34.,  3., 25., 50.,  6.]), -1, True, {})
# (array([21., 87., 34.,  3., 25., 50., 34.,  3., 25., 50.,  6.]), -1, True, {})
# 52
# (array([21., 87., 34.,  3., 25., 50., 34.,  3., 25., 50.,  6.]), -1, True, {})
# (array([21., 87., 34.,  3., 25., 50., 34.,  3., 25., 50.,  6.]), -1, True, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# 2
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  78.,   0.,   0., 579.,  96.,   0.,   0.,   6.]), 0.1, False, {})
# 8
# (array([ 21.,  31., 579., 125.,   0.,   0., 579., 139.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,   0., 579., 147.,   0.,   0., 579., 142.,   0.,   0.,   6.]), 0.1, False, {})
# 11
# (array([ 21.,  37., 579., 106.,   0.,   0., 579.,  90.,   0.,   0.,   6.]), 0.1, False, {})
# 12
# (array([ 21.,  88., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  82., 579.,  79.,   0.,   0., 579., 104.,   0.,   0.,   6.]), 0.1, False, {})
# 15
# (array([ 21.,  11., 579., 145.,   0.,   0., 579., 149.,   0.,   0.,   6.]), 0.1, False, {})
# 16
# (array([ 21.,   5., 579., 142.,   0.,   0., 579., 135.,   0.,   0.,   6.]), 0.1, False, {})
# 18
# (array([ 21.,  31., 579., 113.,   0.,   0., 579.,  90.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  78.,   0.,   0., 579., 105.,   0.,   0.,   6.]), 0.1, False, {})
# 20
# (array([ 21.,  15., 579., 142.,   0.,   0., 579., 146.,   0.,   0.,   6.]), 0.1, False, {})
# 21
# (array([ 21.,   1., 579., 149.,   0.,   0., 579., 144.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  25., 579., 120.,   0.,   0., 579., 107.,   0.,   0.,   6.]), 0.1, False, {})
# 24
# (array([ 21.,  67., 579.,  74.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# (array([ 21.,  93., 579.,  57.,   0.,   0., 579.,  57.,   0.,   0.,   6.]), 0.1, False, {})
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# ...
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# User closed the window
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31262/103578047.py in <module>
#      15             print(game.get_score())
#      16         else :
# ---> 17             print(env.step(0))
#      18     except (NoSuchWindowException, WebDriverException):
#      19         print('User closed the window')
#
# ~/Dev/repos/mbzuai/gym-chrome-dino/gym_chrome_dino/envs/chrome_dino_env.py in step(self, action)
#     154         if action == 3:
#     155             self.game.press_space()
# --> 156         observation = self._observe()
#     157         reward = self.get_score()
#     158         done = False
#
# ~/Dev/repos/mbzuai/gym-chrome-dino/gym_chrome_dino/envs/chrome_dino_env.py in _observe(self)
#     119     def _observe(self):
#     120
# --> 121         dino_position_x = float(self.game.get_dino_x_position())
#     122         dino_position_y = float(self.game.get_dino_y_position())
#     123         first_obstacle_x_distance = float(self.game.get_nth_nearest_obstacle_x_distance(1))
#
# ~/Dev/repos/mbzuai/gym-chrome-dino/gym_chrome_dino/game/dino_game.py in get_dino_x_position(self)
#      86
#      87     def get_dino_x_position(self):
# ---> 88         return self.driver.execute_script('return Runner.instance_.tRex.xPos;')
#      89
#      90     def get_dino_y_position(self):
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/http/client.py in getresponse(self)
#    1346         try:
#    1347             try:
# -> 1348                 response.begin()
#    1349             except ConnectionError:
#    1350                 self.close()
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/http/client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/http/client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# ~/Software/anaconda3/envs/ml_project/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
